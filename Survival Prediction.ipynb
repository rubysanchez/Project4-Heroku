# %%
import pandas as pd
import numpy as np
import sqlalchemy
import csv
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import sqlite3 as sql
from sqlalchemy import create_engine, MetaData, inspect
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float, ForeignKey
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Creating SQLlite Table Structure

# %%
# Create Engine
### BEGIN SOLUTION
engine = create_engine("sqlite:///survivalprediction.sqlite")


### END SOLUTION

# %%
# Use `declarative_base` from SQLAlchemy to model table as an ORM class
# Make sure to specify types for each column

# Declare a Base object here
### BEGIN SOLUTION
Base = declarative_base()

### END SOLUTION

# %%
conn = engine.connect()
conn.text_factory = str

# %%
# Define the ORM class
### BEGIN SOLUTION
class Surv(Base):
    
    __tablename__ = 'prediction'
    
    Primary_Key = Column(Integer, primary_key=True, unique=True)
    Age = Column(String(20))
    Cancer_Stage = Column(String(10))
    Gender = Column(String(10))
    Cancer_Site = Column(String(25))
    Race = Column(String(50))
    Median_Household_Income = Column(String(25))
    Cancer_Type = Column(String(50))

                      
### END SOLUTION

# %%
# Use `create_all` to create the tables
### BEGIN SOLUTION
Base.metadata.create_all(engine)
### END SOLUTION

# %%
inspector = inspect(engine)

# %%
table_names = inspector.get_table_names()
print(table_names)
# Out:
# ['prediction']

# %%
columns = inspector.get_columns('prediction')
for column in columns:
    print(column["name"], column["type"])
# Out:
# Primary_Key INTEGER
# Age VARCHAR(20)
# Cancer_Stage VARCHAR(10)
# Gender VARCHAR(10)
# Cancer_Site VARCHAR(25)
# Race VARCHAR(50)
# Median_Household_Income VARCHAR(25)
# Cancer_Type VARCHAR(50)

# %% [markdown]
# # Data Load/Cleaning Before Machine Learning & DB Creation

# %%
# Loading files in
file = "resources/tester.txt"
data = 'Tester.txt'

# %%
# Read csv
Survival = pd.read_csv(data, encoding = 'utf8')
# Out:
# C:\Users\shawn\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Create dataframe with newly appended data
Survival_DF = pd.DataFrame(Survival)

# %%
# Show DF
Survival_DF.head(5)
# Out:
#       Sex Age recode with single ages and 85+  \
# 0    Male                            73 years
# 1    Male                            66 years
# 2  Female                            54 years
# 3  Female                            82 years
# 4  Female                            56 years
#
#   Median household income inflation adj to 2018  \
# 0                                      $75,000+
# 1                                      $75,000+
# 2                                      $75,000+
# 3                                      $75,000+
# 4                                      $75,000+
#
#         Histology recode - broad groupings  \
# 0  8140-8389: adenomas and adenocarcinomas
# 1  8140-8389: adenomas and adenocarcinomas
# 2  8500-8549: ductal and lobular neoplasms
# 3  8500-8549: ductal and lobular neoplasms
# 4  8500-8549: ductal and lobular neoplasms
#
#   Derived AJCC Stage Group, 7th ed (2010-2015) Survival months  \
# 0                                            I            0082
# 1                                          IIB            0061
# 2                                          IIA            0024
# 3                                           IA            0063
# 4                                           IA            0045
#
#   Race and origin recode (NHW, NHB, NHAIAN, NHAPI, Hispanic)  \
# 0                                 Non-Hispanic White
# 1                                 Non-Hispanic White
# 2                                 Non-Hispanic White
# 3                                 Non-Hispanic White
# 4                                 Non-Hispanic White
#
#   CS Schema - AJCC 6th Edition
# 0                     Prostate
# 1                     Prostate
# 2                       Breast
# 3                       Breast
# 4                       Breast

# %%
# Rename columns
Survival_DF2 = Survival_DF.rename(columns={'Sex': 'Gender', 'Age recode with single ages and 85+':'Age',
       'Median household income inflation adj to 2018':'Median_Household_Income','Histology recode - broad groupings':'Cancer_Type',
       'Derived AJCC Stage Group, 7th ed (2010-2015)':'Cancer_Stage', 'Survival months':'Survival_Months',
       'Race and origin recode (NHW, NHB, NHAIAN, NHAPI, Hispanic)':'Race','CS Schema - AJCC 6th Edition': 'Cancer_Site'})

# %%
# Cleaning up DF 
Survival_DF2 = Survival_DF2.loc[Survival_DF2['Survival_Months'] != 'Unknown']
Survival_DF2 = Survival_DF2.loc[Survival_DF2['Age'] != 'Unknown']
Survival_DF2['Age'] = Survival_DF2['Age'].str.replace(' years','')
Survival_DF2['Age'] = Survival_DF2['Age'].str.replace('+','')
Survival_DF2['Median_Household_Income'] = Survival_DF2['Median_Household_Income'].str.replace('Unknown/missing/no match/Not 1990-2017','Unknown')
# Out:
# <ipython-input-16-4f496eb48e72>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   Survival_DF2['Age'] = Survival_DF2['Age'].str.replace('+','')

# %%
# Collect DF columns
Survival_DF2.columns
# Out:
# Index(['Gender', 'Age', 'Median_Household_Income', 'Cancer_Type',
#        'Cancer_Stage', 'Survival_Months', 'Race', 'Cancer_Site'],
#       dtype='object')

# %%
# Change the type of of object in the column
Survival_DF2['Cancer_Type'] = Survival_DF2['Cancer_Type'].astype(str)

# %%
# Split the string in the column
Survival_DF2['Cancer_Type'] = Survival_DF2['Cancer_Type'].str.split(':').str[1]

# %%
# Capitalize first letter of each word in 'Cancer Type column'
Survival_DF2['Cancer_Type'] = Survival_DF2['Cancer_Type'].str.title()

# %%
# Change the type of of object in the column
Survival_DF2['Survival_Months'] = pd.to_numeric(Survival_DF2['Survival_Months'])
Survival_DF2['Age'] = pd.to_numeric(Survival_DF2['Age'])
Survival_DF2['Age'].dtype
# Out:
# dtype('int64')

# %%
# Display new cleaned DF
Survival_DF2.head()
# Out:
#    Gender  Age Median_Household_Income                    Cancer_Type  \
# 0    Male   73                $75,000+   Adenomas And Adenocarcinomas
# 1    Male   66                $75,000+   Adenomas And Adenocarcinomas
# 2  Female   54                $75,000+   Ductal And Lobular Neoplasms
# 3  Female   82                $75,000+   Ductal And Lobular Neoplasms
# 4  Female   56                $75,000+   Ductal And Lobular Neoplasms
#
#   Cancer_Stage  Survival_Months                Race Cancer_Site
# 0            I               82  Non-Hispanic White    Prostate
# 1          IIB               61  Non-Hispanic White    Prostate
# 2          IIA               24  Non-Hispanic White      Breast
# 3           IA               63  Non-Hispanic White      Breast
# 4           IA               45  Non-Hispanic White      Breast

# %%
# Drop all rows with missing information
df_clean_data = Survival_DF2.dropna(how='any')

# %%
#Iterate through rows to identify what columns have null values
for column in df_clean_data.columns:
    print(f"Column {column} has {df_clean_data[column].isnull().sum()} null values")
# Out:
# Column Gender has 0 null values
# Column Age has 0 null values
# Column Median_Household_Income has 0 null values
# Column Cancer_Type has 0 null values
# Column Cancer_Stage has 0 null values
# Column Survival_Months has 0 null values
# Column Race has 0 null values
# Column Cancer_Site has 0 null values

# %%
# Cleaned new DF
df_clean_data.head()
# Out:
#    Gender  Age Median_Household_Income                    Cancer_Type  \
# 0    Male   73                $75,000+   Adenomas And Adenocarcinomas
# 1    Male   66                $75,000+   Adenomas And Adenocarcinomas
# 2  Female   54                $75,000+   Ductal And Lobular Neoplasms
# 3  Female   82                $75,000+   Ductal And Lobular Neoplasms
# 4  Female   56                $75,000+   Ductal And Lobular Neoplasms
#
#   Cancer_Stage  Survival_Months                Race Cancer_Site
# 0            I               82  Non-Hispanic White    Prostate
# 1          IIB               61  Non-Hispanic White    Prostate
# 2          IIA               24  Non-Hispanic White      Breast
# 3           IA               63  Non-Hispanic White      Breast
# 4           IA               45  Non-Hispanic White      Breast

# %% [markdown]
# # SQLlite DB Creation

# %%
Survival_DF3 = df_clean_data.drop(['Survival_Months'], axis=1)

# %%
Final = Survival_DF3.drop_duplicates()
Final.head()
# Out:
#    Gender  Age Median_Household_Income                    Cancer_Type  \
# 0    Male   73                $75,000+   Adenomas And Adenocarcinomas
# 1    Male   66                $75,000+   Adenomas And Adenocarcinomas
# 2  Female   54                $75,000+   Ductal And Lobular Neoplasms
# 3  Female   82                $75,000+   Ductal And Lobular Neoplasms
# 4  Female   56                $75,000+   Ductal And Lobular Neoplasms
#
#   Cancer_Stage                Race Cancer_Site
# 0            I  Non-Hispanic White    Prostate
# 1          IIB  Non-Hispanic White    Prostate
# 2          IIA  Non-Hispanic White      Breast
# 3           IA  Non-Hispanic White      Breast
# 4           IA  Non-Hispanic White      Breast

# %%
Base.metadata.create_all(engine)

# %%
#Convert csv data to dictionary
CancerSurvival = Final.to_dict(orient='records')
#View first row of dictionary
CancerSurvival[0]
# Out:
# {'Gender': 'Male',
#  'Age': 73,
#  'Median_Household_Income': '$75,000+',
#  'Cancer_Type': ' Adenomas And Adenocarcinomas',
#  'Cancer_Stage': 'I',
#  'Race': 'Non-Hispanic White',
#  'Cancer_Site': 'Prostate'}

# %%
metadata = MetaData(bind=engine)
metadata.reflect()

# %%
#Create sqlalchemy table
SurvivalTable = sqlalchemy.Table('prediction', metadata, autoload=True)

# %%
#Insert dictionary data into sqlalchemy table
conn.execute(SurvivalTable.insert(), CancerSurvival)

# %%
#View sqlalchemy table data
conn.execute("select * from prediction").fetchall()
# Out:
# [(1, '73', 'I', 'Male', 'Prostate', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (2, '66', 'IIB', 'Male', 'Prostate', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (3, '54', 'IIA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (4, '82', 'IA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (5, '56', 'IA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (6, '85', 'I', 'Male', 'Bladder', 'Non-Hispanic White', '$75,000+', ' Transitional Cell Papillomas And Carcinomas'),
#  (7, '67', 'IIIB', 'Female', 'Rectum', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (8, '85', 'IIIB', 'Female', 'Breast', 'Non-Hispanic Black', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (9, '71', 'IA', 'Female', 'Breast', 'Hispanic (All Races)', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (10, '76', 'IV', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (11, '60', 'IIA', 'Male', 'Prostate', 'Non-Hispanic Black', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (12, '75', 'IV', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (13, '69', 'IA', 'Female', 'Lung', 'Non-Hispanic Black', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (14, '85', 'IIIC', 'Female', 'Breast', 'Hispanic (All Races)', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (15, '80', 'IIB', 'Male', 'Prostate', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (16, '70', 'IIIA', 'Female', 'Colon', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (17, '59', 'IA', 'Female', 'Melanoma', 'Non-Hispanic White', '$75,000+', ' Nevi And Melanomas'),
#  (18, '80', 'IIB', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Acinar Cell Neoplasms'),
#  (19, '69', 'IV', 'Male', 'SmallIntestine', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (20, '84', 'IIIC1', 'Female', 'Corpus', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (21, '60', 'IIA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (22, '61', 'IA', 'Female', 'Corpus', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (23, '52', 'IA', 'Female', 'Corpus', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (24, '85', 'I', 'Female', 'SmallIntestine', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (25, '64', 'IIB', 'Male', 'Stomach', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (26, '68', 'IA', 'Female', 'Corpus', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Complex Mixed And Stromal Neoplasms'),
#  (27, '57', 'IIIA', 'Male', 'SmallIntestine', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (28, '57', 'I', 'Male', 'Kidney', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (29, '84', 'IIB', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (30, '85', 'I', 'Male', 'Rectum', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (31, '53', 'III', 'Male', 'Thyroid', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (32, '85', 'IV', 'Male', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (33, '49', 'IB', 'Male', 'Melanoma', 'Non-Hispanic White', '$75,000+', ' Nevi And Melanomas'),
#  (34, '45', 'I', 'Female', 'Thyroid', 'Hispanic (All Races)', '$75,000+', ' Squamous Cell Neoplasms'),
#  (35, '46', 'IIIC', 'Female', 'Ovary', 'Non-Hispanic White', '$75,000+', ' Cystic, Mucinous And Serous Neoplasms'),
#  (36, '72', 'IV', 'Female', 'Lung', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (37, '61', 'IA', 'Female', 'Breast', 'Non-Hispanic Black', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (38, '83', 'IA', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  
#  (92, '64', 'III', 'Male', 'Lung', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (93, '80', 'IB', 'Female', 'Breast', 'Non-Hispanic Black', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (94, '80', 'IA', 'Female', 'Breast', 'Non-Hispanic Black', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (95, '82', 'IIA', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (96, '85', 'IV', 'Female', 'Lymphoma', 'Non-Hispanic White', '$75,000+', ' Nhl - Mature B-Cell Lymphomas'),
#  (97, '85', 'IIIA', 'Male', 'Stomach', 'Non-Hispanic Black', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (98, '55', 'IIA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (99, '77', 'IA', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (100, '45', 'IA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (101, '78', 'IA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (102, '85', 'IV', 'Male', 'Prostate', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (103, '85', 'IIA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Cystic, Mucinous And Serous Neoplasms'),
#  (104, '64', 'IIA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (105, '85', 'IA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (106, '84', 'INOS', 'Male', 'Melanoma', 'Non-Hispanic White', '$75,000+', ' Nevi And Melanomas'),
#  (107, '85', 'IA', 'Male', 'Melanoma', 'Non-Hispanic White', '$75,000+', ' Nevi And Melanomas'),
#  (108, '68', 'IIA', 'Female', 'Rectum', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (109, '82', '0a', 'Male', 'Bladder', 'Non-Hispanic White', '$75,000+', ' Transitional Cell Papillomas And Carcinomas'),
#  (110, '69', 'IV', 'Male', 'Prostate', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (111, '70', 'IIIA', 'Male', 'Lung', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (112, '82', 'I', 'Female', 'Pleura', 'Non-Hispanic White', '$75,000+', ' Mesothelial Neoplasms'),
#  (113, '64', 'IA', 'Female', 'Ovary', 'Non-Hispanic White', '$75,000+', ' Cystic, Mucinous And Serous Neoplasms'),
#  (114, '80', 'IV', 'Female', 'Kidney', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (115, '70', 'IB', 'Female', 'Vulva', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (116, '83', 'IA', 'Male', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (117, '56', 'IA', 'Male', 'Melanoma', 'Non-Hispanic White', '$75,000+', ' Nevi And Melanomas'),
#  (118, '71', 'IIA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (119, '77', 'IIB', 'Male', 'Prostate', 'Hispanic (All Races)', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (120, '69', 'I', 'Male', 'Kidney', 'Non-Hispanic Black', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (121, '77', 'IV', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (122, '63', 'IA', 'Female', 'Corpus', 'Non-Hispanic Black', '$75,000+', ' Complex Mixed And Stromal Neoplasms'),
#  (123, '57', 'I', 'Female', 'Kidney', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (124, '68', 'IA', 'Male', 'Melanoma', 'Non-Hispanic White', '$75,000+', ' Nevi And Melanomas'),
#  (125, '62', 'IA', 'Female', 'Corpus', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (126, '44', 'IIA', 'Female', 'Breast', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (127, '80', '0a', 'Male', 'Bladder', 'Non-Hispanic White', '$75,000+', ' Transitional Cell Papillomas And Carcinomas'),
#  (128, '68', 'IIIB', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (129, '72', 'IVA', 'Male', 'BaseTongue', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (130, '85', 'IV', 'Female', 'PancreasBodyTail', 'Non-Hispanic White', '$75,000+', ' Unspecified Neoplasms'),
#  (131, '85', 'IIA', 'Female', 'Rectum', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (132, '35', 'IA', 'Female', 'Melanoma', 'Non-Hispanic White', '$75,000+', ' Nevi And Melanomas'),
#  (133, '85', 'III', 'Male', 'PancreasHead', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (134, '72', 'I', 'Female', 'Kidney', 'Hispanic (All Races)', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (135, '68', 'IV', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (136, '85', 'IIA', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (137, '84', 'IIINOS', 'Female', 'Vulva', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (138, '85', 'IVA', 'Female', 'Lymphoma', 'Non-Hispanic White', '$75,000+', ' Hodgkin Lymphomas'),
#  (139, '59', 'IA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (140, '68', 'IA', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (141, '85', 'II', 'Male', 'Bladder', 'Non-Hispanic White', '$75,000+', ' Transitional Cell Papillomas And Carcinomas'),
#  (142, '74', 'IIA', 'Male', 'PancreasHead', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (143, '63', 'IIIB', 'Female', 'Breast', 'Hispanic (All Races)', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (144, '85', 'IIIA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (145, '82', 'IIB', 'Male', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (146, '85', 'II', 'Male', 'Skin', 'Non-Hispanic White', '$75,000+', ' Adnexal And Skin Appendage Neoplasms'),
#  (147, '66', 'I', 'Female', 'Thyroid', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (148, '84', 'IV', 'Male', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  
'$75,000+', ' Adenomas And Adenocarcinomas'),
#  (178, '85', 'IIIB', 'Male', 'Rectum', 'Hispanic (All Races)', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (179, '80', 'II', 'Male', 'Bladder', 'Non-Hispanic White', '$75,000+', ' Transitional Cell Papillomas And Carcinomas'),
#  (180, '85', 'IIA', 'Male', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (181, '70', 'IIIB', 'Female', 'Lymphoma', 'Non-Hispanic White', '$75,000+', ' Nhl - Mature B-Cell Lymphomas'),
#  (182, '68', '0a', 'Male', 'Bladder', 'Non-Hispanic White', '$75,000+', ' Transitional Cell Papillomas And Carcinomas'),
#  (183, '64', 'IV', 'Female', 'SmallIntestine', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (184, '62', 'IV', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (185, '83', 'IIIA', 'Female', 'Breast', 'Hispanic (All Races)', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (186, '56', 'I', 'Male', 'Prostate', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (187, '55', 'IA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (188, '80', 'II', 'Female', 'Liver', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (189, '76', 'IA', 'Female', 'Lung', 'Hispanic (All Races)', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (190, '79', 'IVB', 'Male', 'Lymphoma', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Hodgkin Lymphomas'),
#  (191, '83', 'II', 'Female', 'Liver', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (192, '74', 'IIA', 'Male', 'Prostate', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (193, '67', 'I', 'Male', 'Liver', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (194, '62', 'III', 'Male', 'BaseTongue', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (195, '67', 'I', 'Female', 'Anus', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (196, '41', 'IA', 'Male', 'PancreasBodyTail', 'Hispanic (All Races)', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (197, '64', 'IV', 'Male', 'Kidney', 'Non-Hispanic White', '$75,000+', ' Unspecified Neoplasms'),
#  (198, '81', 'IIA', 'Male', 'Colon', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (199, '50', 'IIIC', 'Male', 'Colon', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (200, '51', 'IA', 'Female', 'Corpus', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (201, '78', 'IA', 'Male', 'Lung', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (202, '42', 'IB', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (203, '76', 'IIIA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (204, '77', 'IIA', 'Female', 'Lung', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  
'$75,000+', ' Adenomas And Adenocarcinomas'),
#  (265, '68', 'IA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Cystic, Mucinous And Serous Neoplasms'),
#  (266, '73', 'IB', 'Male', 'Melanoma', 'Non-Hispanic White', '$75,000+', ' Nevi And Melanomas'),
#  (267, '60', 'II', 'Male', 'Oropharynx', 'Non-Hispanic Black', '$75,000+', ' Squamous Cell Neoplasms'),
#  (268, '85', 'IIA', 'Female', 'Breast', 'Hispanic (All Races)', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (269, '49', '0a', 'Female', 'Bladder', 'Non-Hispanic White', '$75,000+', ' Transitional Cell Papillomas And Carcinomas'),
#  (270, '70', 'IA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (271, '80', 'I', 'Female', 'Thyroid', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (272, '78', 'IV', 'Female', 'Esophagus', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (273, '51', 'IA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (274, '69', 'IA', 'Female', 'Corpus', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (275, '70', 'IA', 'Female', 'Melanoma', 'Non-Hispanic White', '$75,000+', ' Nevi And Melanomas'),
#  (276, '82', 'IIB', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (277, '68', 'III', 'Male', 'AntTongue', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (278, '69', 'II', 'Male', 'FOM', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (279, '83', 'IIA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (280, '85', 'IE', 'Male', 'Lymphoma', 'Non-Hispanic White', '$75,000+', ' Nhl - Mature B-Cell Lymphomas'),
#  (281, '85', '0a', 'Female', 'Bladder', 'Non-Hispanic White', '$75,000+', ' Transitional Cell Papillomas And Carcinomas'),
#  (282, '71', 'I', 'Female', 'Thyroid', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Squamous Cell Neoplasms'),
#  (283, '80', 'IV', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (284, '73', 'IV', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (285, '55', 'I', 'Male', 'Rectum', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (286, '82', 'IIA', 'Male', 'Colon', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (287, '85', 'IV', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (288, '64', 'IIA', 'Male', 'Prostate', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  
'$75,000+', ' Adenomas And Adenocarcinomas'),
#  (344, '84', 'INOS', 'Female', 'Melanoma', 'Non-Hispanic White', '$75,000+', ' Nevi And Melanomas'),
#  (345, '85', 'IA', 'Male', 'SkinEyelid', 'Non-Hispanic White', '$75,000+', ' Adnexal And Skin Appendage Neoplasms'),
#  (346, '68', 'IIB', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (347, '82', 'IIA', 'Female', 'Colon', 'Non-Hispanic Black', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (348, '85', 'IV', 'Female', 'Peritoneum', 'Hispanic (All Races)', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (349, '85', 'IA', 'Male', 'Stomach', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (350, '81', 'IIB', 'Female', 'Lung', 'Hispanic (All Races)', '$75,000+', ' Squamous Cell Neoplasms'),
#  (351, '79', '0a', 'Male', 'Bladder', 'Non-Hispanic White', '$75,000+', ' Transitional Cell Papillomas And Carcinomas'),
#  (352, '82', 'IIIA', 'Female', 'Corpus', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (353, '85', 'INOS', 'Female', 'Melanoma', 'Non-Hispanic White', '$75,000+', ' Nevi And Melanomas'),
#  (354, '70', 'IIA', 'Female', 'Breast', 'Non-Hispanic Black', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (355, '75', 'IIIA', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (356, '83', 'IA', 'Female', 'Corpus', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (357, '81', 'IA', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (358, '82', 'I', 'Female', 'Kidney', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (359, '71', 'IB', 'Female', 'Lung', 'Hispanic (All Races)', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (360, '80', 'II', 'Female', 'Anus', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (361, '85', 'IIA', 'Female', 'Breast', 'Non-Hispanic Black', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (362, '85', 'IIB', 'Male', 'Esophagus', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (363, '85', 'IV', 'Female', 'Ovary', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (364, '57', 'IA', 'Female', 'Breast', 'Non-Hispanic White', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (365, '85', 'IIB', 'Male', 'Prostate', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (366, '76', 'IIB', 'Female', 'Esophagus', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (367, '85', 'IVB', 'Female', 'Rectum', 'Non-Hispanic White', '$75,000+', ' Unspecified Neoplasms'),
#  (368, '76', 'IV', 'Female', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (369, '85', 'IEA', 'Female', 'Lymphoma', 'Non-Hispanic White', '$75,000+', ' Nhl - Mature B-Cell Lymphomas'),
#  (370, '82', 'IIIA', 'Male', 'Lung', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (371, '66', 'IVB', 'Female', 'Rectum', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  
'$75,000+', ' Adenomas And Adenocarcinomas'),
#  (903, '85', 'IIA', 'Female', 'Rectum', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (904, '78', 'IVB', 'Male', 'Colon', 'Non-Hispanic Black', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (905, '62', 'III', 'Female', 'SoftTissue', 'Non-Hispanic White', '$75,000+', ' Blood Vessel Tumors'),
#  (906, '71', 'IVA', 'Female', 'Lymphoma', 'Non-Hispanic White', '$75,000+', ' Nhl - Mature B-Cell Lymphomas'),
#  (907, '75', 'I', 'Male', 'Colon', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (908, '77', 'I', 'Male', 'Colon', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (909, '85', 'IIA', 'Female', 'OthPancreas', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (910, '62', 'II', 'Female', 'Anus', 'Non-Hispanic White', '$75,000+', ' Squamous Cell Neoplasms'),
#  (911, '62', 'IV', 'Female', 'Breast', 'Non-Hispanic Black', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (912, '83', 'IVB', 'Male', 'Lymphoma', 'Non-Hispanic White', '$75,000+', ' Nhl - Mature T And Nk-Cell Lymphomas'),
#  (913, '80', 'IIA', 'Female', 'Colon', 'Non-Hispanic Black', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (914, '81', 'IV', 'Female', 'Bladder', 'Non-Hispanic Black', '$75,000+', ' Transitional Cell Papillomas And Carcinomas'),
#  (915, '51', 'IV', 'Male', 'OthPancreas', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (916, '61', 'I', 'Male', 'Thyroid', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (917, '71', 'IB', 'Female', 'Lung', 'Non-Hispanic Black', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (918, '80', 'II', 'Female', 'Gallbladder', 'Non-Hispanic Black', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (919, '69', 'IVA', 'Female', 'Thyroid', 'Hispanic (All Races)', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (920, '85', 'IA', 'Female', 'Lymphoma', 'Non-Hispanic White', '$75,000+', ' Lymphoid Leukemias (C42.1)'),
#  (921, '85', 'IVB', 'Female', 'Lymphoma', 'Non-Hispanic White', '$75,000+', ' Hodgkin Lymphomas'),
#  (922, '49', 'INOS', 'Female', 'Corpus', 'Hispanic (All Races)', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (923, '59', 'IV', 'Female', 'Kidney', 'Non-Hispanic Black', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (924, '79', 'IA', 'Female', 'Breast', 'Non-Hispanic Black', '$75,000+', ' Ductal And Lobular Neoplasms'),
#  (925, '82', 'IIB', 'Male', 'Lung', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (926, '81', 'IVB', 'Male', 'Liver', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (927, '85', 'IVB', 'Male', 'Rectum', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (928, '77', 'IIA', 'Female', 'Colon', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (929, '78', 'IVA', 'Male', 'Rectum', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (930, '85', 'IIEA', 'Female', 'Lymphoma', 'Non-Hispanic White', '$75,000+', ' Malignant Lymphomas, Nos Or Diffuse'),
#  (931, '85', '0is', 'Male', 'Bladder', 'Non-Hispanic Black', '$75,000+', ' Transitional Cell Papillomas And Carcinomas'),
#  (932, '60', 'IV', 'Male', 'RenalPelvis', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (933, '73', 'IVB', 'Male', 'Oropharynx', 'Hispanic (All Races)', '$75,000+', ' Squamous Cell Neoplasms'),
#  (934, '77', 'IV', 'Female', 'OthPancreas', 'Non-Hispanic Black', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  
'$75,000+', ' Adenomas And Adenocarcinomas'),
#  (994, '77', 'IV', 'Male', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (995, '71', 'IIA', 'Male', 'Colon', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (996, '65', 'IVA', 'Female', 'Lymphoma', 'Non-Hispanic Black', '$75,000+', ' Malignant Lymphomas, Nos Or Diffuse'),
#  (997, '85', 'IV', 'Male', 'PancreasHead', 'Non-Hispanic White', '$75,000+', ' Epithelial Neoplasms, Nos'),
#  (998, '85', 'IV', 'Female', 'Peritoneum', 'Non-Hispanic Asian or Pacific Islander', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  (999, '71', 'IA', 'Male', 'Lung', 'Non-Hispanic White', '$75,000+', ' Cystic, Mucinous And Serous Neoplasms'),
#  (1000, '71', 'IA', 'Male', 'Lung', 'Non-Hispanic White', '$75,000+', ' Adenomas And Adenocarcinomas'),
#  ...]

# %% [markdown]
# # Flask Test

# %%
engine = create_engine("sqlite:///survivalprediction.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save reference to the table
CS = Base.classes.prediction

# %%
session = Session(engine)

# %% [markdown]
# Cancer Site

# %%
# Query for unique cancer site names
cancer_site_results = session.query(CS.Cancer_Site).distinct()

# %%
    session.close()

    cancer_site_list = []
    for Cancer_Site in cancer_site_results:
        cancer_site_dict = {}
        cancer_site_dict["Cancer_Site"] = Cancer_Site
        cancer_site_list.append(cancer_site_dict)

# %%
print(cancer_site_list)
# Out:
# [{'Cancer_Site': ('Prostate',)}, {'Cancer_Site': ('Breast',)}, {'Cancer_Site': ('Bladder',)}, {'Cancer_Site': ('Rectum',)}, {'Cancer_Site': ('Lung',)}, {'Cancer_Site': ('Colon',)}, {'Cancer_Site': ('Melanoma',)}, {'Cancer_Site': ('SmallIntestine',)}, {'Cancer_Site': ('Corpus',)}, {'Cancer_Site': ('Stomach',)}, {'Cancer_Site': ('Kidney',)}, {'Cancer_Site': ('Thyroid',)}, {'Cancer_Site': ('Ovary',)}, {'Cancer_Site': ('Lymphoma',)}, {'Cancer_Site': ('SkinEyelid',)}, {'Cancer_Site': ('MF',)}, {'Cancer_Site': ('SoftTissue',)}, {'Cancer_Site': ('Vulva',)}, {'Cancer_Site': ('Urethra',)}, {'Cancer_Site': ('PancreasHead',)}, {'Cancer_Site': ('PancreasBodyTail',)}, {'Cancer_Site': ('Pleura',)}, {'Cancer_Site': ('BaseTongue',)}, {'Cancer_Site': ('Skin',)}, {'Cancer_Site': ('SupraLarynx',)}, {'Cancer_Site': ('OthPancreas',)}, {'Cancer_Site': ('Liver',)}, {'Cancer_Site': ('Anus',)}, {'Cancer_Site': ('GumUpper',)}, {'Cancer_Site': ('GumLower',)}, {'Cancer_Site': ('Oropharynx',)}, {'Cancer_Site': ('Esophagus',)}, {'Cancer_Site': ('AntTongue',)}, {'Cancer_Site': ('FOM',)}, {'Cancer_Site': ('ExtraHepaticDucts',)}, {'Cancer_Site': ('SoftPalate',)}, {'Cancer_Site': ('Gallbladder',)}, {'Cancer_Site': ('Peritoneum',)}, {'Cancer_Site': ('Ampulla',)}, {'Cancer_Site': ('Cervix',)}, {'Cancer_Site': ('FallopianTube',)}, {'Cancer_Site': ('ParotidGland',)}, {'Cancer_Site': ('Hypopharynx',)}, {'Cancer_Site': ('RenalPelvis',)}, {'Cancer_Site': ('GlotticLarynx',)}, {'Cancer_Site': ('Bone',)}, {'Cancer_Site': ('SubmandibularGland',)}, {'Cancer_Site': ('Vagina',)}, {'Cancer_Site': ('LipUpper',)}, {'Cancer_Site': ('NasalCavity',)}, {'Cancer_Site': ('MaxillarySinus',)}, {'Cancer_Site': ('Nasopharynx',)}, {'Cancer_Site': ('OthLarynx',)}, {'Cancer_Site': ('Penis',)}, {'Cancer_Site': ('LipLower',)}, {'Cancer_Site': ('BuccalMucosa',)}, {'Cancer_Site': ('MelanomaIrisCiliary',)}, {'Cancer_Site': ('Testis',)}, {'Cancer_Site': ('MelanomaChoroid',)}, {'Cancer_Site': ('OthGum',)}, {'Cancer_Site': ('HardPalate',)}, {'Cancer_Site': ('OthSalivary',)}, {'Cancer_Site': ('SubLarynx',)}, {'Cancer_Site': ('Scrotum',)}, {'Cancer_Site': ('OthMouth',)}, {'Cancer_Site': ('OthLip',)}, {'Cancer_Site': ('HemeRetic',)}, {'Cancer_Site': ('OthEndocrine',)}, {'Cancer_Site': ('AntEpiglottis',)}, {'Cancer_Site': ('EthmoidSinus',)}, {'Cancer_Site': ('HeartMediastinum',)}, {'Cancer_Site': ('Placenta',)}, {'Cancer_Site': ('OthPharynx',)}]

# %% [markdown]
# Median Household Income

# %%
Median_Household_Income_Results = session.query(CS.Median_Household_Income).distinct()

# %%
    session.close()

    median_household_income_list = []
    for Median_Household_Income in Median_Household_Income_Results:
        median_household_income_dict = {}
        median_household_income_dict["Median_Household_Income"] = Median_Household_Income
        median_household_income_list.append(median_household_income_dict)
        
print(median_household_income_list)
# Out:
# [{'Median_Household_Income': ('$75,000+',)}, {'Median_Household_Income': ('$65,000 - $69,999',)}, {'Median_Household_Income': ('$70,000 - $74,999',)}, {'Median_Household_Income': ('$60,000 - $64,999',)}, {'Median_Household_Income': ('$55,000 - $59,999',)}, {'Median_Household_Income': ('$40,000 - $44,999',)}, {'Median_Household_Income': ('$45,000 - $49,999',)}, {'Median_Household_Income': ('$50,000 - $54,999',)}, {'Median_Household_Income': ('$35,000 - $39,999',)}, {'Median_Household_Income': ('< $35,000',)}, {'Median_Household_Income': ('Unknown',)}]

# %% [markdown]
# Race

# %%
Race_Results = session.query(CS.Race).distinct()

# %%
    session.close()

    race_list = []
    for Race in Race_Results:
        race_dict = {}
        race_dict["Race"] = Race
        race_list.append(race_dict)
        
print(race_list)
# Out:
# [{'Race': ('Non-Hispanic White',)}, {'Race': ('Non-Hispanic Asian or Pacific Islander',)}, {'Race': ('Non-Hispanic Black',)}, {'Race': ('Hispanic (All Races)',)}, {'Race': ('Non-Hispanic American Indian/Alaska Native',)}, {'Race': ('Non-Hispanic Unknown Race',)}]

# %% [markdown]
# Cancer Stage

# %%
Cancer_Stage_Results = session.query(CS.Cancer_Stage).distinct()

# %%
    session.close()

    cancer_stage_list = []
    for Cancer_Stage in Cancer_Stage_Results:
        cancer_stage_dict = {}
        cancer_stage_dict["Cancer_Stage"] = Cancer_Stage
        cancer_stage_list.append(cancer_stage_dict)
        
print(cancer_stage_list)
# Out:
# [{'Cancer_Stage': ('I',)}, {'Cancer_Stage': ('IIB',)}, {'Cancer_Stage': ('IIA',)}, {'Cancer_Stage': ('IA',)}, {'Cancer_Stage': ('IIIB',)}, {'Cancer_Stage': ('IV',)}, {'Cancer_Stage': ('IIIC',)}, {'Cancer_Stage': ('IIIA',)}, {'Cancer_Stage': ('IIIC1',)}, {'Cancer_Stage': ('III',)}, {'Cancer_Stage': ('IB',)}, {'Cancer_Stage': ('IEA',)}, {'Cancer_Stage': ('OCCULT',)}, {'Cancer_Stage': ('0a',)}, {'Cancer_Stage': ('IVB',)}, {'Cancer_Stage': ('IVA',)}, {'Cancer_Stage': ('II',)}, {'Cancer_Stage': ('INOS',)}, {'Cancer_Stage': ('IIINOS',)}, {'Cancer_Stage': ('IIIEA',)}, {'Cancer_Stage': ('IIEA',)}, {'Cancer_Stage': ('IVC',)}, {'Cancer_Stage': ('IIC',)}, {'Cancer_Stage': ('IE',)}, {'Cancer_Stage': ('IIEB',)}, {'Cancer_Stage': ('0is',)}, {'Cancer_Stage': ('IINOS',)}, {'Cancer_Stage': ('IB2',)}, {'Cancer_Stage': ('IIIESB',)}, {'Cancer_Stage': ('0',)}, {'Cancer_Stage': ('IVNOS',)}, {'Cancer_Stage': ('IIIC2',)}, {'Cancer_Stage': ('ISA',)}, {'Cancer_Stage': ('IIE',)}, {'Cancer_Stage': ('IBNOS',)}, {'Cancer_Stage': ('IA1',)}, {'Cancer_Stage': ('IB1',)}, {'Cancer_Stage': ('IC',)}, {'Cancer_Stage': ('IIA2',)}, {'Cancer_Stage': ('IIISA',)}, {'Cancer_Stage': ('IIIE',)}, {'Cancer_Stage': ('IEB',)}, {'Cancer_Stage': ('IISA',)}, {'Cancer_Stage': ('IIIEB',)}, {'Cancer_Stage': ('IIESB',)}, {'Cancer_Stage': ('IIISB',)}, {'Cancer_Stage': ('IVA1',)}, {'Cancer_Stage': ('IISB',)}, {'Cancer_Stage': ('IA2',)}, {'Cancer_Stage': ('IIIESA',)}, {'Cancer_Stage': ('IIESA',)}, {'Cancer_Stage': ('IS',)}, {'Cancer_Stage': ('IIS',)}, {'Cancer_Stage': ('IIANOS',)}, {'Cancer_Stage': ('IVA2',)}, {'Cancer_Stage': ('IIA1',)}, {'Cancer_Stage': ('IIIS',)}, {'Cancer_Stage': ('IANOS',)}, {'Cancer_Stage': ('ISB',)}, {'Cancer_Stage': ('IIES',)}, {'Cancer_Stage': ('IIIES',)}]

# %% [markdown]
# Cancer Type

# %%
Cancer_Type_Results = session.query(CS.Cancer_Type).distinct()

# %%
    session.close()

    cancer_type_list = []
    for Cancer_Type in Cancer_Type_Results:
        cancer_type_dict = {}
        cancer_type_dict["Cancer_Type"] = Cancer_Type
        cancer_type_list.append(cancer_type_dict)
        
print(cancer_type_list)
# Out:
# [{'Cancer_Type': (' Adenomas And Adenocarcinomas',)}, {'Cancer_Type': (' Ductal And Lobular Neoplasms',)}, {'Cancer_Type': (' Transitional Cell Papillomas And Carcinomas',)}, {'Cancer_Type': (' Epithelial Neoplasms, Nos',)}, {'Cancer_Type': (' Nevi And Melanomas',)}, {'Cancer_Type': (' Acinar Cell Neoplasms',)}, {'Cancer_Type': (' Complex Mixed And Stromal Neoplasms',)}, {'Cancer_Type': (' Squamous Cell Neoplasms',)}, {'Cancer_Type': (' Cystic, Mucinous And Serous Neoplasms',)}, {'Cancer_Type': (' Nhl - Mature B-Cell Lymphomas',)}, {'Cancer_Type': (' Adnexal And Skin Appendage Neoplasms',)}, {'Cancer_Type': (' Nhl - Mature T And Nk-Cell Lymphomas',)}, {'Cancer_Type': (' Blood Vessel Tumors',)}, {'Cancer_Type': (' Soft Tissue Tumors And Sarcomas, Nos',)}, {'Cancer_Type': (' Complex Epithelial Neoplasms',)}, {'Cancer_Type': (' Mesothelial Neoplasms',)}, {'Cancer_Type': (' Unspecified Neoplasms',)}, {'Cancer_Type': (' Hodgkin Lymphomas',)}, {'Cancer_Type': (' Mucoepidermoid Neoplasms',)}, {'Cancer_Type': (' Nhl - Precursor Cell Lymphoblastic Lymphoma',)}, {'Cancer_Type': (' Lymphoid Leukemias (C42.1)',)}, {'Cancer_Type': (' Lipomatous Neoplasms',)}, {'Cancer_Type': (' Malignant Lymphomas, Nos Or Diffuse',)}, {'Cancer_Type': (' Miscellaneous Tumors',)}, {'Cancer_Type': (' Osseous And Chondromatous Neoplasms',)}, {'Cancer_Type': (' Myomatous Neoplasms',)}, {'Cancer_Type': (' Fibromatous Neoplasms',)}, {'Cancer_Type': (' Fibroepithelial Neoplasms',)}, {'Cancer_Type': (' Germ Cell Neoplasms',)}, {'Cancer_Type': (' Plasma Cell Tumors',)}, {'Cancer_Type': (' Synovial-Like Neoplasms',)}, {'Cancer_Type': (' Basal Cell Neoplasms',)}, {'Cancer_Type': (' Specialized Gonadal Neoplasms',)}, {'Cancer_Type': (' Miscellaneous Bone Tumors (C40._, C41._)',)}, {'Cancer_Type': (' Nerve Sheath Tumors',)}, {'Cancer_Type': (' Gliomas',)}, {'Cancer_Type': (' Neuroepitheliomatous Neoplasms',)}, {'Cancer_Type': (' Trophoblastic Neoplasms',)}, {'Cancer_Type': (' Granular Cell Tumors & Alveolar Soft Part Sarcoma',)}, {'Cancer_Type': (' Odontogenic Tumors (C41._)',)}, {'Cancer_Type': (' Myxomatous Neoplasms',)}, {'Cancer_Type': (' Lymphatic Vessel Tumors',)}, {'Cancer_Type': (' Giant Cell Tumors',)}, {'Cancer_Type': (' Mesonephromas',)}]

# %% [markdown]
# Age

# %%
Age_Results = session.query(CS.Age).distinct()

# %%
    session.close()

    age_list = []
    for Age in Age_Results:
        age_dict = {}
        age_dict["Age"] = Age
        age_list.append(age_dict)
        
print(age_list)
# Out:
# [{'Age': ('73',)}, {'Age': ('66',)}, {'Age': ('54',)}, {'Age': ('82',)}, {'Age': ('56',)}, {'Age': ('85',)}, {'Age': ('67',)}, {'Age': ('71',)}, {'Age': ('76',)}, {'Age': ('60',)}, {'Age': ('75',)}, {'Age': ('69',)}, {'Age': ('80',)}, {'Age': ('70',)}, {'Age': ('59',)}, {'Age': ('84',)}, {'Age': ('61',)}, {'Age': ('52',)}, {'Age': ('64',)}, {'Age': ('68',)}, {'Age': ('57',)}, {'Age': ('53',)}, {'Age': ('49',)}, {'Age': ('45',)}, {'Age': ('46',)}, {'Age': ('72',)}, {'Age': ('83',)}, {'Age': ('74',)}, {'Age': ('58',)}, {'Age': ('62',)}, {'Age': ('81',)}, {'Age': ('79',)}, {'Age': ('78',)}, {'Age': ('55',)}, {'Age': ('77',)}, {'Age': ('63',)}, {'Age': ('44',)}, {'Age': ('35',)}, {'Age': ('23',)}, {'Age': ('34',)}, {'Age': ('65',)}, {'Age': ('41',)}, {'Age': ('50',)}, {'Age': ('51',)}, {'Age': ('42',)}, {'Age': ('40',)}, {'Age': ('48',)}, {'Age': ('38',)}, {'Age': ('47',)}, {'Age': ('39',)}, {'Age': ('43',)}, {'Age': ('25',)}, {'Age': ('37',)}, {'Age': ('31',)}, {'Age': ('20',)}, {'Age': ('19',)}, {'Age': ('28',)}, {'Age': ('29',)}, {'Age': ('36',)}, {'Age': ('32',)}, {'Age': ('22',)}, {'Age': ('24',)}, {'Age': ('33',)}, {'Age': ('11',)}, {'Age': ('12',)}, {'Age': ('26',)}, {'Age': ('10',)}, {'Age': ('30',)}, {'Age': ('17',)}, {'Age': ('27',)}, {'Age': ('21',)}, {'Age': ('15',)}, {'Age': ('18',)}, {'Age': ('13',)}, {'Age': ('0',)}, {'Age': ('9',)}, {'Age': ('2',)}, {'Age': ('7',)}, {'Age': ('8',)}, {'Age': ('16',)}, {'Age': ('4',)}, {'Age': ('1',)}, {'Age': ('3',)}, {'Age': ('14',)}, {'Age': ('5',)}, {'Age': ('6',)}]

# %% [markdown]
# Gender

# %%
Gender_Results = session.query(CS.Gender).distinct()

# %%
    session.close()

    gender_list = []
    for Gender in Gender_Results:
        gender_dict = {}
        gender_dict["Gender"] = Gender
        gender_list.append(gender_dict)
        
print(gender_list)
# Out:
# [{'Gender': ('Male',)}, {'Gender': ('Female',)}]

# %%
    session.close()

# %% [markdown]
# # Machine Learning Sample Data Frame

# %%
# Utilizing a sample of cleaned DF due to length of running our models
df_sample = df_clean_data.sample(frac=.15)
df_sample.head()
# Out:
#          Gender  Age Median_Household_Income                    Cancer_Type  \
# 346359   Female   79                $75,000+   Adenomas And Adenocarcinomas
# 289043     Male   60       $40,000 - $44,999   Adenomas And Adenocarcinomas
# 389584   Female   84       $55,000 - $59,999   Adenomas And Adenocarcinomas
# 151133   Female   58                $75,000+   Ductal And Lobular Neoplasms
# 1256080    Male   62                $75,000+   Adenomas And Adenocarcinomas
#
#         Cancer_Stage  Survival_Months                                    Race  \
# 346359          IIIB               68  Non-Hispanic Asian or Pacific Islander
# 289043           IIA               28                      Non-Hispanic Black
# 389584          IIIC               23                      Non-Hispanic White
# 151133           IIA                8                    Hispanic (All Races)
# 1256080            I               46                      Non-Hispanic White
#
#         Cancer_Site
# 346359        Colon
# 289043     Prostate
# 389584        Colon
# 151133       Breast
# 1256080    Prostate

# %%
y_sample = df_sample['Survival_Months']
y_sample = y_sample.round()
y_sample
# Out:
# 346359     68
# 289043     28
# 389584     23
# 151133      8
# 1256080    46
#            ..
# 115577     41
# 821727      3
# 109954     43
# 898885     61
# 960105     34
# Name: Survival_Months, Length: 315140, dtype: int64

# %%
testing_data_sample = df_sample.drop(['Survival_Months'], axis=1)
testing_data_sample
# Out:
#          Gender  Age Median_Household_Income                    Cancer_Type  \
# 346359   Female   79                $75,000+   Adenomas And Adenocarcinomas
# 289043     Male   60       $40,000 - $44,999   Adenomas And Adenocarcinomas
# 389584   Female   84       $55,000 - $59,999   Adenomas And Adenocarcinomas
# 151133   Female   58                $75,000+   Ductal And Lobular Neoplasms
# 1256080    Male   62                $75,000+   Adenomas And Adenocarcinomas
# ...         ...  ...                     ...                            ...
# 115577     Male   64                $75,000+   Adenomas And Adenocarcinomas
# 821727   Female   60       $60,000 - $64,999   Ductal And Lobular Neoplasms
# 109954     Male   74       $65,000 - $69,999   Adenomas And Adenocarcinomas
# 898885     Male   63       $55,000 - $59,999   Adenomas And Adenocarcinomas
# 960105   Female   75       $60,000 - $64,999   Adenomas And Adenocarcinomas
#
#         Cancer_Stage                                    Race Cancer_Site
# 346359          IIIB  Non-Hispanic Asian or Pacific Islander       Colon
# 289043           IIA                      Non-Hispanic Black    Prostate
# 389584          IIIC                      Non-Hispanic White       Colon
# 151133           IIA                    Hispanic (All Races)      Breast
# 1256080            I                      Non-Hispanic White    Prostate
# ...              ...                                     ...         ...
# 115577            IA                      Non-Hispanic White        Lung
# 821727            IV                    Hispanic (All Races)      Breast
# 109954           IIA                      Non-Hispanic White     Ampulla
# 898885             I                    Hispanic (All Races)      Kidney
# 960105            IV                      Non-Hispanic White        Lung
#
# [315140 rows x 7 columns]

# %%
X_sample = pd.get_dummies(testing_data_sample)
X_sample
# Out:
#          Age  Gender_Female  Gender_Male  \
# 346359    79              1            0
# 289043    60              0            1
# 389584    84              1            0
# 151133    58              1            0
# 1256080   62              0            1
# ...      ...            ...          ...
# 115577    64              0            1
# 821727    60              1            0
# 109954    74              0            1
# 898885    63              0            1
# 960105    75              1            0
#
#          Median_Household_Income_$35,000 - $39,999  \
# 346359                                           0
# 289043                                           0
# 389584                                           0
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           0
# 109954                                           0
# 898885                                           0
# 960105                                           0
#
#          Median_Household_Income_$40,000 - $44,999  \
# 346359                                           0
# 289043                                           1
# 389584                                           0
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           0
# 109954                                           0
# 898885                                           0
# 960105                                           0
#
#          Median_Household_Income_$45,000 - $49,999  \
# 346359                                           0
# 289043                                           0
# 389584                                           0
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           0
# 109954                                           0
# 898885                                           0
# 960105                                           0
#
#          Median_Household_Income_$50,000 - $54,999  \
# 346359                                           0
# 289043                                           0
# 389584                                           0
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           0
# 109954                                           0
# 898885                                           0
# 960105                                           0
#
#          Median_Household_Income_$55,000 - $59,999  \
# 346359                                           0
# 289043                                           0
# 389584                                           1
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           0
# 109954                                           0
# 898885                                           1
# 960105                                           0
#
#          Median_Household_Income_$60,000 - $64,999  \
# 346359                                           0
# 289043                                           0
# 389584                                           0
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           1
# 109954                                           0
# 898885                                           0
# 960105                                           1
#
#          Median_Household_Income_$65,000 - $69,999  ...  \
# 346359                                           0  ...
# 289043                                           0  ...
# 389584                                           0  ...
# 151133                                           0  ...
# 1256080                                          0  ...
# ...                                            ...  ...
# 115577                                           0  ...
# 821727                                           0  ...
# 109954                                           1  ...
# 898885                                           0  ...
# 960105                                           0  ...
#
#          Cancer_Site_SoftTissue  Cancer_Site_Stomach  Cancer_Site_SubLarynx  \
# 346359                        0                    0                      0
# 289043                        0                    0                      0
# 389584                        0                    0                      0
# 151133                        0                    0                      0
# 1256080                       0                    0                      0
# ...                         ...                  ...                    ...
# 115577                        0                    0                      0
# 821727                        0                    0                      0
# 109954                        0                    0                      0
# 898885                        0                    0                      0
# 960105                        0                    0                      0
#
#          Cancer_Site_SubmandibularGland  Cancer_Site_SupraLarynx  \
# 346359                                0                        0
# 289043                                0                        0
# 389584                                0                        0
# 151133                                0                        0
# 1256080                               0                        0
# ...                                 ...                      ...
# 115577                                0                        0
# 821727                                0                        0
# 109954                                0                        0
# 898885                                0                        0
# 960105                                0                        0
#
#          Cancer_Site_Testis  Cancer_Site_Thyroid  Cancer_Site_Urethra  \
# 346359                    0                    0                    0
# 289043                    0                    0                    0
# 389584                    0                    0                    0
# 151133                    0                    0                    0
# 1256080                   0                    0                    0
# ...                     ...                  ...                  ...
# 115577                    0                    0                    0
# 821727                    0                    0                    0
# 109954                    0                    0                    0
# 898885                    0                    0                    0
# 960105                    0                    0                    0
#
#          Cancer_Site_Vagina  Cancer_Site_Vulva
# 346359                    0                  0
# 289043                    0                  0
# 389584                    0                  0
# 151133                    0                  0
# 1256080                   0                  0
# ...                     ...                ...
# 115577                    0                  0
# 821727                    0                  0
# 109954                    0                  0
# 898885                    0                  0
# 960105                    0                  0
#
# [315140 rows x 196 columns]

# %% [markdown]
# # Supervised Machine Learning

# %% [markdown]
# ### Random Forest Classifier

# %%
#Creating three categories to prepare data for classification
df_sample.loc[df_sample['Survival_Months'] <7, 'Survival Groups'] = '0-6 Months'
df_sample.loc[(df_sample['Survival_Months'] >=7) & (df_sample['Survival_Months'] <= 12), 'Survival Groups'] = '7-12 Months'
df_sample.loc[df_sample['Survival_Months'] >12, 'Survival Groups'] = '> 12 Months'
df_sample
# Out:
#          Gender  Age Median_Household_Income                    Cancer_Type  \
# 346359   Female   79                $75,000+   Adenomas And Adenocarcinomas
# 289043     Male   60       $40,000 - $44,999   Adenomas And Adenocarcinomas
# 389584   Female   84       $55,000 - $59,999   Adenomas And Adenocarcinomas
# 151133   Female   58                $75,000+   Ductal And Lobular Neoplasms
# 1256080    Male   62                $75,000+   Adenomas And Adenocarcinomas
# ...         ...  ...                     ...                            ...
# 115577     Male   64                $75,000+   Adenomas And Adenocarcinomas
# 821727   Female   60       $60,000 - $64,999   Ductal And Lobular Neoplasms
# 109954     Male   74       $65,000 - $69,999   Adenomas And Adenocarcinomas
# 898885     Male   63       $55,000 - $59,999   Adenomas And Adenocarcinomas
# 960105   Female   75       $60,000 - $64,999   Adenomas And Adenocarcinomas
#
#         Cancer_Stage  Survival_Months                                    Race  \
# 346359          IIIB               68  Non-Hispanic Asian or Pacific Islander
# 289043           IIA               28                      Non-Hispanic Black
# 389584          IIIC               23                      Non-Hispanic White
# 151133           IIA                8                    Hispanic (All Races)
# 1256080            I               46                      Non-Hispanic White
# ...              ...              ...                                     ...
# 115577            IA               41                      Non-Hispanic White
# 821727            IV                3                    Hispanic (All Races)
# 109954           IIA               43                      Non-Hispanic White
# 898885             I               61                    Hispanic (All Races)
# 960105            IV               34                      Non-Hispanic White
#
#         Cancer_Site Survival Groups
# 346359        Colon     > 12 Months
# 289043     Prostate     > 12 Months
# 389584        Colon     > 12 Months
# 151133       Breast     7-12 Months
# 1256080    Prostate     > 12 Months
# ...             ...             ...
# 115577         Lung     > 12 Months
# 821727       Breast      0-6 Months
# 109954      Ampulla     > 12 Months
# 898885       Kidney     > 12 Months
# 960105         Lung     > 12 Months
#
# [315140 rows x 9 columns]

# %%
#Create y with new 'Survival Groups' column
y_sample = df_sample['Survival Groups']

#Encode Y_Train and Y_Test
y_sample = LabelEncoder().fit_transform(df_sample['Survival Groups'])

y_sample
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
#Drop old target and new target columns
testing_data_sample = df_sample.drop(['Survival_Months'], axis=1)
testing_data_sample = testing_data_sample.drop(['Survival Groups'], axis=1)

testing_data_sample
# Out:
#          Gender  Age Median_Household_Income                    Cancer_Type  \
# 346359   Female   79                $75,000+   Adenomas And Adenocarcinomas
# 289043     Male   60       $40,000 - $44,999   Adenomas And Adenocarcinomas
# 389584   Female   84       $55,000 - $59,999   Adenomas And Adenocarcinomas
# 151133   Female   58                $75,000+   Ductal And Lobular Neoplasms
# 1256080    Male   62                $75,000+   Adenomas And Adenocarcinomas
# ...         ...  ...                     ...                            ...
# 115577     Male   64                $75,000+   Adenomas And Adenocarcinomas
# 821727   Female   60       $60,000 - $64,999   Ductal And Lobular Neoplasms
# 109954     Male   74       $65,000 - $69,999   Adenomas And Adenocarcinomas
# 898885     Male   63       $55,000 - $59,999   Adenomas And Adenocarcinomas
# 960105   Female   75       $60,000 - $64,999   Adenomas And Adenocarcinomas
#
#         Cancer_Stage                                    Race Cancer_Site
# 346359          IIIB  Non-Hispanic Asian or Pacific Islander       Colon
# 289043           IIA                      Non-Hispanic Black    Prostate
# 389584          IIIC                      Non-Hispanic White       Colon
# 151133           IIA                    Hispanic (All Races)      Breast
# 1256080            I                      Non-Hispanic White    Prostate
# ...              ...                                     ...         ...
# 115577            IA                      Non-Hispanic White        Lung
# 821727            IV                    Hispanic (All Races)      Breast
# 109954           IIA                      Non-Hispanic White     Ampulla
# 898885             I                    Hispanic (All Races)      Kidney
# 960105            IV                      Non-Hispanic White        Lung
#
# [315140 rows x 7 columns]

# %%
#Convert x values to dummy values
X_dummies = pd.get_dummies(testing_data_sample)
X_dummies
# Out:
#          Age  Gender_Female  Gender_Male  \
# 346359    79              1            0
# 289043    60              0            1
# 389584    84              1            0
# 151133    58              1            0
# 1256080   62              0            1
# ...      ...            ...          ...
# 115577    64              0            1
# 821727    60              1            0
# 109954    74              0            1
# 898885    63              0            1
# 960105    75              1            0
#
#          Median_Household_Income_$35,000 - $39,999  \
# 346359                                           0
# 289043                                           0
# 389584                                           0
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           0
# 109954                                           0
# 898885                                           0
# 960105                                           0
#
#          Median_Household_Income_$40,000 - $44,999  \
# 346359                                           0
# 289043                                           1
# 389584                                           0
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           0
# 109954                                           0
# 898885                                           0
# 960105                                           0
#
#          Median_Household_Income_$45,000 - $49,999  \
# 346359                                           0
# 289043                                           0
# 389584                                           0
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           0
# 109954                                           0
# 898885                                           0
# 960105                                           0
#
#          Median_Household_Income_$50,000 - $54,999  \
# 346359                                           0
# 289043                                           0
# 389584                                           0
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           0
# 109954                                           0
# 898885                                           0
# 960105                                           0
#
#          Median_Household_Income_$55,000 - $59,999  \
# 346359                                           0
# 289043                                           0
# 389584                                           1
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           0
# 109954                                           0
# 898885                                           1
# 960105                                           0
#
#          Median_Household_Income_$60,000 - $64,999  \
# 346359                                           0
# 289043                                           0
# 389584                                           0
# 151133                                           0
# 1256080                                          0
# ...                                            ...
# 115577                                           0
# 821727                                           1
# 109954                                           0
# 898885                                           0
# 960105                                           1
#
#          Median_Household_Income_$65,000 - $69,999  ...  \
# 346359                                           0  ...
# 289043                                           0  ...
# 389584                                           0  ...
# 151133                                           0  ...
# 1256080                                          0  ...
# ...                                            ...  ...
# 115577                                           0  ...
# 821727                                           0  ...
# 109954                                           1  ...
# 898885                                           0  ...
# 960105                                           0  ...
#
#          Cancer_Site_SoftTissue  Cancer_Site_Stomach  Cancer_Site_SubLarynx  \
# 346359                        0                    0                      0
# 289043                        0                    0                      0
# 389584                        0                    0                      0
# 151133                        0                    0                      0
# 1256080                       0                    0                      0
# ...                         ...                  ...                    ...
# 115577                        0                    0                      0
# 821727                        0                    0                      0
# 109954                        0                    0                      0
# 898885                        0                    0                      0
# 960105                        0                    0                      0
#
#          Cancer_Site_SubmandibularGland  Cancer_Site_SupraLarynx  \
# 346359                                0                        0
# 289043                                0                        0
# 389584                                0                        0
# 151133                                0                        0
# 1256080                               0                        0
# ...                                 ...                      ...
# 115577                                0                        0
# 821727                                0                        0
# 109954                                0                        0
# 898885                                0                        0
# 960105                                0                        0
#
#          Cancer_Site_Testis  Cancer_Site_Thyroid  Cancer_Site_Urethra  \
# 346359                    0                    0                    0
# 289043                    0                    0                    0
# 389584                    0                    0                    0
# 151133                    0                    0                    0
# 1256080                   0                    0                    0
# ...                     ...                  ...                  ...
# 115577                    0                    0                    0
# 821727                    0                    0                    0
# 109954                    0                    0                    0
# 898885                    0                    0                    0
# 960105                    0                    0                    0
#
#          Cancer_Site_Vagina  Cancer_Site_Vulva
# 346359                    0                  0
# 289043                    0                  0
# 389584                    0                  0
# 151133                    0                  0
# 1256080                   0                  0
# ...                     ...                ...
# 115577                    0                  0
# 821727                    0                  0
# 109954                    0                  0
# 898885                    0                  0
# 960105                    0                  0
#
# [315140 rows x 196 columns]

# %%
X_sample = X_dummies

# %%
X = X_sample
y = y_sample

# Choose your test size to split between training and testing sets:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
#Run classification model
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train, y_train)
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 0.9313236445177805
# Testing Score: 0.8019039157199974

# %%
# Placing our predication data in CSV
predication_data = pd.Series(0,index=X_train.columns)
predication_data.to_csv('resources/Blank_Form.csv')

# %%
# Creating a model to read csv inputs from webiste
model.predict(np.reshape(np.array(predication_data.values.tolist()),(1,198)))

# %%
# The model and its placed in apy file as well
def modelFunction(model_name, model):
    import pickle 
    with open(str(model_name), "wb") as f:
        pickle.dump(model,f)

# %%
# Model function
modelFunction("resources/model.pkl", model)

# %%
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=500, centers=4,
                  random_state=0, cluster_std=1.0)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow')

# %% [markdown]
# ##### All the code below was our trial and error period fro different models. We tried utilizing full data sets and it caused the model to run almost for 20-30+ minutes. After models were ran we still recieved similar scores to samples. All of the code in the next cell isn't needed, but there for learning purposes.

# %%
#### Linear Regression Model

# y = df_clean_data['Survival_Months']
# testing_data = df_clean_data.drop('Survival_Months', axis=1)
# X = pd.get_dummies(testing_data)
# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# model.fit(X_train, y_train)
# print(f"Training Data Score: {model.score(X_train, y_train)}")
# print(f"Testing Data Score: {model.score(X_test, y_test)}")

# %%
#### Random Forest Model

# model = GradientBoostingRegressor()
# model.fit(X_train, y_train)
# print(f"Training Data Score: {model.score(X_train, y_train)}")
# print(f"Testing Data Score: {model.score(X_test, y_test)}")
# predicated = model.predict(X_test)
# mean_absolute_error(y_test,predicated)
